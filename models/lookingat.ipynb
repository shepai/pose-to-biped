# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=np.load("/home/dexter/Documents/GitHub/pose-to-biped/models/X.npy")
mask = data == None
count = np.sum(mask)

print(count)
print(data.shape)
# Out:
# 0
# (118967, 33, 4)

# %%
learning_PPO=np.load("/home/dexter/Documents/GitHub/pose-to-biped/models/results/log_ppo.npy")
#learning_SAC=np.load("/home/dexter/Documents/GitHub/pose-to-biped/models/results/log_sac.npy")
k = 5000
n = len(learning_PPO)

x = np.arange(min(k, n))
# First 10k
plt.plot(x,
         learning_PPO[:k],
         "b",
         label=f"First {k//1000}k")

# Last 10k
start = max(n - k, 0)
plt.plot(x,
         learning_PPO[start:],
         "r",
         label=f"Last {k//1000}k")
#plt.ylim([-5,5])
plt.legend()
plt.show()

"""plt.plot(learning_SAC[:],label="SAC")
mask = learning_PPO == None
count = np.sum(mask)

print(count)"""
print(len(learning_PPO[start:]))
print(len(learning_PPO[:k]))
# Out:
# 5000
# 5000

# %%
import numpy as np
import matplotlib.pyplot as plt

learning_PPO = np.load("/home/dexter/Documents/GitHub/pose-to-biped/models/results/log_ppo.npy")

plt.figure(figsize=(20, 4))  # 👈 make it wide (try 20–40)

plt.plot(learning_PPO)
plt.ylim([-5, 5])

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_250617/3022001770.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
